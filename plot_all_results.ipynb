# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("custom_model_pred_sympy.txt", sep=',')
df.head()
# Out:
#    n   x_front   y_front    x_rear    y_rear  x_predicted  y_predicted  \
# 0  1  0.085457  0.725153  0.081316  0.742710     0.081360     0.742809
# 1  2 -0.183330  0.564817 -0.187163  0.577993    -0.187151     0.578007
# 2  3  0.141934  0.713034  0.140713  0.726720     0.140755     0.726678
# 3  4  0.131086  0.581334  0.130019  0.593710     0.130032     0.593785
# 4  5  0.177168  0.696000  0.176699  0.716003     0.176672     0.715991
#
#    x_correct  y_correct
# 0      0.097      0.753
# 1     -0.183      0.591
# 2      0.155      0.739
# 3      0.145      0.607
# 4      0.193      0.726

# %%
df.plot(x='n',figsize=(20,10))

# %%
df.plot(x='n',y=['x_correct','x_rear'],figsize=(20,10))

# %%
df.plot(x='n',y=['y_correct','y_rear'],figsize=(20,10))

# %%
df.plot(x='n',y=['x_correct','x_front'],figsize=(20,10))

# %%
df.plot(x='n',y=['y_correct','y_front'],figsize=(20,10))

# %%
df.plot(x='n',y=['x_predicted','x_rear'],figsize=(20,10))

# %%
df.plot(x='n',y=['y_predicted','y_rear'],figsize=(20,10))

# %%
df.plot(x='n',y=['x_predicted','x_front'],figsize=(20,10))

# %%
df.plot(x='n',y=['y_predicted','y_front'],figsize=(20,10))

# %%
df.plot(x='n',y=['x_correct','x_predicted','x_front'],figsize=(20,10))

# %%
df.plot(x='n',y=['y_correct','y_predicted','y_front'],figsize=(20,10))

# %%
df.plot(x='n',y=['x_correct','x_predicted','x_rear'],figsize=(20,10))

# %%
df.plot(x='n',y=['y_correct','y_predicted','y_rear'],figsize=(20,10))
